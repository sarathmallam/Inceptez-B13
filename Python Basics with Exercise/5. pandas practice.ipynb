# %%
# !pip install pandas

# %%
import pandas as pd

pd
# Out:
# <module 'pandas' from 'C:\\Users\\SarathBabuMallam\\anaconda3\\lib\\site-packages\\pandas\\__init__.py'>

# %%
sampleData = {
    'Sachin' : [100,105,50,20,95],
    'Sourav' : [183,101,19, 48,7]
}

scores = pd.DataFrame(sampleData)
scores
# Out:
#    Sachin  Sourav
# 0     100     183
# 1     105     101
# 2      50      19
# 3      20      48
# 4      95       7

# %%
data = {
    'orange' : [3,2,0,1],
    'apples' : [0,3,7,2]
    
}

#fruits = pd.DataFrame(data,index=['one','two','three','four'])
fruits = pd.DataFrame(data)

# %%
fruits.loc[0:,'apples']
# Out:
# 0    0
# 1    3
# 2    7
# 3    2
# Name: apples, dtype: int64

# %%
fruits.iloc[0:,]
# Out:
#    orange  apples
# 0       3       0
# 1       2       3
# 2       0       7
# 3       1       2

# %% [markdown]
# #

# %%
fruits.iloc[0:,0]
# Out:
# 0    3
# 1    2
# 2    0
# 3    1
# Name: orange, dtype: int64

# %%
fruits = pd.DataFrame(data,index=['one','two','three','four'])

# %%
fruits.iloc[2:,1]
# Out:
# three    7
# four     2
# Name: apples, dtype: int64

# %%
fruits.loc['three':,'orange']
# Out:
# three    0
# four     1
# Name: orange, dtype: int64

# %%
fruits
# Out:
#        orange  apples
# one         3       0
# two         2       3
# three       0       7
# four        1       2

# %%
fruits['orange']['two']
# Out:
# 2

# %%
fruits.iloc[2]
# Out:
# orange    0
# apples    7
# Name: three, dtype: int64

# %%
import os

# %%
os.listdir()
# Out:
# ['.DS_Store',
#  '.ipynb_checkpoints',
#  'database.db',
#  'Exercise_pandas.ipynb',
#  'IMDB-Movie-Data.csv',
#  'new_purchases.csv',
#  'new_purchases.json',
#  'pandas practice.ipynb',
#  'Pandas_basics.ipynb',
#  'purchases.csv',
#  'purchases.json',
#  'Sample.csv',
#  'Sample.xlsx']

# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is D63E-6211
#
#  Directory of C:\Users\SarathBabuMallam\Desktop\Data science\Python\Inceptz-Batch13-Analytics_and_Python-master\Inceptz-Batch13-Analytics_and_Python-master\05 - Day 5 - Pandas with Exercises
#
# 17-04-2020  12:54    <DIR>          .
# 17-04-2020  12:54    <DIR>          ..
# 13-04-2020  14:29             6,148 .DS_Store
# 17-04-2020  11:52    <DIR>          .ipynb_checkpoints
# 13-04-2020  14:29            12,288 database.db
# 13-04-2020  14:29            14,360 Exercise_pandas.ipynb
# 13-04-2020  14:29           309,767 IMDB-Movie-Data.csv
# 13-04-2020  14:29                60 new_purchases.csv
# 13-04-2020  14:29               102 new_purchases.json
# 17-04-2020  12:54            10,542 pandas practice.ipynb
# 17-04-2020  12:46         1,096,340 Pandas_basics.ipynb
# 13-04-2020  14:29                60 purchases.csv
# 13-04-2020  14:29               102 purchases.json
# ...

# %% [markdown]
# # Methods of reading Data into pandas dataframe!

# %%
#importing CSV files
df = pd.read_csv('us-500.csv')
df
# Out:
#     first_name  last_name                   company_name  \
# 0        James       Butt              Benton, John B Jr
# 1    Josephine    Darakjy          Chanay, Jeffrey A Esq
# 2          Art     Venere            Chemel, James L Cpa
# 3        Lenna   Paprocki         Feltz Printing Service
# 4      Donette     Foller            Printing Dimensions
# ..         ...        ...                            ...
# 495    Brittni  Gillaspie                    Inner Label
# 496    Raylene      Kampa                     Hermar Inc
# 497        Flo   Bookamer   Simonton Howe & Schneider Pc
# 498       Jani      Biddy  Warehouse Office & Paper Prod
# 499   Chauncey     Motley     Affiliated With Travelodge
#
#                   address         city      county state    zip        phone1  \
# 0      6649 N Blue Gum St  New Orleans     Orleans    LA  70116  504-621-8927
# 1     4 B Blue Ridge Blvd     Brighton  Livingston    MI  48116  810-292-9388
# ...

# %%
df.loc[0]
# Out:
# first_name                             James
# last_name                               Butt
# company_name               Benton, John B Jr
# address                   6649 N Blue Gum St
# city                             New Orleans
# county                               Orleans
# state                                     LA
# zip                                    70116
# phone1                          504-621-8927
# phone2                          504-845-1427
# email                        jbutt@gmail.com
# web             http://www.bentonjohnbjr.com
# Name: 0, dtype: object

# %%
df.loc[0][0]
# Out:
# 'James'

# %%
df.loc[0:,'zip']
# Out:
# 0      70116
# 1      48116
# 2       8014
# 3      99501
# 4      45011
#        ...
# 495    83709
# 496    46514
# 497    69301
# 498    98104
# 499    32804
# Name: zip, Length: 500, dtype: int64

# %%
df.iloc[499:,2]
# Out:
# 499    Affiliated With Travelodge
# Name: company_name, dtype: object

# %%
rf = pd.read_csv('https://raw.githubusercontent.com/codeforamerica/ohana-api/master/data/sample-csv/addresses.csv')
rf
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
df = pd.read_json("purchases.json")
df
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
df.loc['June']
# Out:
# apples     3
# oranges    0
# Name: June, dtype: int64

# %%
df.loc['June']['apples']
# Out:
# 3

# %%
df.iloc[2:,]
# Out:
#        apples  oranges
# Lily        0        7
# David       1        2

# %%
df.iloc[2:,1]
# Out:
# Lily     7
# David    2
# Name: oranges, dtype: int64

# %% [markdown]
# # How to open a database file

# %%
# !pip install pysqlite3
# Out:
# ...
#   Running setup.py clean for pysqlite3
# Failed to build pysqlite3
# ...
#     Running setup.py install for pysqlite3: started
#     Running setup.py install for pysqlite3: finished with status 'done'
# ...
#   WARNING: Legacy build of wheel for 'pysqlite3' created no files.
#   Command arguments: 'C:\Users\SarathBabuMallam\anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\SARATH~1\\AppData\\Local\\Temp\\pip-install-e_n8ag1x\\pysqlite3\\setup.py'"'"'; __file__='"'"'C:\\Users\\SARATH~1\\AppData\\Local\\Temp\\pip-install-e_n8ag1x\\pysqlite3\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\SARATH~1\AppData\Local\Temp\pip-wheel-bjzgc27o'
#   Command output: [use --verbose to show]

# %%
import sqlite3 as sql

con = sql.connect('database.db')

# %%
df = pd.read_sql_query('SELECT * FROM purchases where apples >0',con)
df
# Out:
#     index  apples  oranges
# 0    June       3        0
# 1  Robert       2        3
# 2   David       1        2

# %%
df.size
# Out:
# 9

# %%
len(df)
# Out:
# 3

# %%
df = df.set_index('index')
df
# Out:
#         apples  oranges
# index
# June         3        0
# Robert       2        3
# David        1        2

# %%
df.size
# Out:
# 6

# %% [markdown]
# # Writing it back into different formats

# %%
df.to_excel('sampleexcel.xlsx',index=False)

# %%
df.to_csv('sample,csv',sep=':')

# %% [markdown]
# # Important operations in a dataframe

# %%
movies_df = pd.read_csv("IMDB-Movie-Data.csv",index_col="Title")

# %%
movies_df
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
movies_df.shape
# Out:
# (1000, 11)

# %%
movies_df.head()
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %%
movies_df.head(10)
# Out:
#                          Rank                       Genre  \
# Title
# Guardians of the Galaxy     1     Action,Adventure,Sci-Fi
# Prometheus                  2    Adventure,Mystery,Sci-Fi
# Split                       3             Horror,Thriller
# Sing                        4     Animation,Comedy,Family
# Suicide Squad               5    Action,Adventure,Fantasy
# The Great Wall              6    Action,Adventure,Fantasy
# La La Land                  7          Comedy,Drama,Music
# Mindhorn                    8                      Comedy
# The Lost City of Z          9  Action,Adventure,Biography
# Passengers                 10     Adventure,Drama,Romance
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# ...

# %%
movies_df.tail()
# Out:
#                         Rank                  Genre  \
# Title
# Secret in Their Eyes     996    Crime,Drama,Mystery
# Hostel: Part II          997                 Horror
# Step Up 2: The Streets   998    Drama,Music,Romance
# Search Party             999       Adventure,Comedy
# Nine Lives              1000  Comedy,Family,Fantasy
#
#                                                               Description  \
# Title
# Secret in Their Eyes    A tight-knit team of rising investigators, alo...
# Hostel: Part II         Three American college students studying abroa...
# Step Up 2: The Streets  Romantic sparks occur between two dance studen...
# Search Party            A pair of friends embark on a mission to reuni...
# Nine Lives              A stuffy businessman finds himself trapped ins...
#
#                                 Director  \
# Title
# Secret in Their Eyes           Billy Ray
# Hostel: Part II                 Eli Roth
# Step Up 2: The Streets        Jon M. Chu
# ...

# %%
movies_df.tail(10)
# Out:
#                                 Rank                     Genre  \
# Title
# Underworld: Rise of the Lycans   991  Action,Adventure,Fantasy
# Taare Zameen Par                 992        Drama,Family,Music
# Take Me Home Tonight             993      Comedy,Drama,Romance
# Resident Evil: Afterlife         994   Action,Adventure,Horror
# Project X                        995                    Comedy
# Secret in Their Eyes             996       Crime,Drama,Mystery
# Hostel: Part II                  997                    Horror
# Step Up 2: The Streets           998       Drama,Music,Romance
# Search Party                     999          Adventure,Comedy
# Nine Lives                      1000     Comedy,Family,Fantasy
#
#                                                                       Description  \
# Title
# Underworld: Rise of the Lycans  An origins story centered on the centuries-old...
# Taare Zameen Par                An eight-year-old boy is thought to be a lazy ...
# ...

# %%
movies_df.loc[movies_df['Rank']==991]
# Out:
#                                 Rank                     Genre  \
# Title
# Underworld: Rise of the Lycans   991  Action,Adventure,Fantasy
#
#                                                                       Description  \
# Title
# Underworld: Rise of the Lycans  An origins story centered on the centuries-old...
#
#                                           Director  \
# Title
# Underworld: Rise of the Lycans  Patrick Tatopoulos
#
#                                                                            Actors  \
# Title
# Underworld: Rise of the Lycans  Rhona Mitra, Michael Sheen, Bill Nighy, Steven...
#
#                                 Year  Runtime (Minutes)  Rating   Votes  \
# Title
# Underworld: Rise of the Lycans  2009                 92     6.6  129708
#
#                                 Revenue (Millions)  Metascore
# Title
# Underworld: Rise of the Lycans                45.8       44.0

# %%
movies_df.loc[(movies_df['Rank']==991)]
# Out:
#                                 Rank                     Genre  \
# Title
# Underworld: Rise of the Lycans   991  Action,Adventure,Fantasy
#
#                                                                       Description  \
# Title
# Underworld: Rise of the Lycans  An origins story centered on the centuries-old...
#
#                                           Director  \
# Title
# Underworld: Rise of the Lycans  Patrick Tatopoulos
#
#                                                                            Actors  \
# Title
# Underworld: Rise of the Lycans  Rhona Mitra, Michael Sheen, Bill Nighy, Steven...
#
#                                 Year  Runtime (Minutes)  Rating   Votes  \
# Title
# Underworld: Rise of the Lycans  2009                 92     6.6  129708
#
#                                 Revenue (Millions)  Metascore
# Title
# Underworld: Rise of the Lycans                45.8       44.0

# %%
movies_df.columns
# Out:
# Index(['Rank', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-95-8240472ffa6e> in <module>
# ----> 1 movies_df.rows
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 133.8+ KB

# %%
type(movies_df)
# Out:
# pandas.core.frame.DataFrame

# %%
movies_df.shape
# Out:
# (1000, 11)

# %% [markdown]
# # Duplicates

# %%
duplicates_df = movies_df.append(movies_df)

# %%
duplicates_df.shape
# Out:
# (2000, 11)

# %%
duplicates_df.loc[duplicates_df['Rank']==991]
# Out:
#                                 Rank                     Genre  \
# Title
# Underworld: Rise of the Lycans   991  Action,Adventure,Fantasy
# Underworld: Rise of the Lycans   991  Action,Adventure,Fantasy
#
#                                                                       Description  \
# Title
# Underworld: Rise of the Lycans  An origins story centered on the centuries-old...
# Underworld: Rise of the Lycans  An origins story centered on the centuries-old...
#
#                                           Director  \
# Title
# Underworld: Rise of the Lycans  Patrick Tatopoulos
# Underworld: Rise of the Lycans  Patrick Tatopoulos
#
#                                                                            Actors  \
# Title
# Underworld: Rise of the Lycans  Rhona Mitra, Michael Sheen, Bill Nighy, Steven...
# Underworld: Rise of the Lycans  Rhona Mitra, Michael Sheen, Bill Nighy, Steven...
#
#                                 Year  Runtime (Minutes)  Rating   Votes  \
# Title
# ...

# %%
duplicates_df = duplicates_df.drop_duplicates(inplace = False)
#not working

# %%
duplicates_df.shape
# Out:
# (2000, 11)

# %%
duplicates_df = duplicates_df.drop_duplicates(inplace = True)

# %%
duplicates_df.shape
# Out:
# (2000, 11)

# %%
duplicates_df = duplicates_df.drop_duplicates()

# %%
duplicates_df.shape
# Out:
# (1000, 11)

# %%
duplicates_df
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
movies_copy_df = movies_df

movies_copy_df['Rank']
movies_df['Rank']
# Out:
# Title
# Guardians of the Galaxy       1
# Prometheus                    2
# Split                         3
# Sing                          4
# Suicide Squad                 5
#                            ...
# Secret in Their Eyes        996
# Hostel: Part II             997
# Step Up 2: The Streets      998
# Search Party                999
# Nine Lives                 1000
# Name: Rank, Length: 1000, dtype: int64

# %%
movies_copy_df['Rank'] = range(1000,2000,1)

# %%
movies_df['Rank']
# Out:
# Title
# Guardians of the Galaxy    1000
# Prometheus                 1001
# Split                      1002
# Sing                       1003
# Suicide Squad              1004
#                            ...
# Secret in Their Eyes       1995
# Hostel: Part II            1996
# Step Up 2: The Streets     1997
# Search Party               1998
# Nine Lives                 1999
# Name: Rank, Length: 1000, dtype: int32

# %%
duplicate_df_rank = movies_df.append(movies_copy_df)

# %%
duplicate_df_rank['Rank']
# Out:
# Title
# Guardians of the Galaxy    1000
# Prometheus                 1001
# Split                      1002
# Sing                       1003
# Suicide Squad              1004
#                            ...
# Secret in Their Eyes       1995
# Hostel: Part II            1996
# Step Up 2: The Streets     1997
# Search Party               1998
# Nine Lives                 1999
# Name: Rank, Length: 2000, dtype: int32

# %%
duplicates_df
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
duplicate_df_rank.drop_duplicates(subset=['Rank','Year'],inplace = False)
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy  1000   Action,Adventure,Sci-Fi
# Prometheus               1001  Adventure,Mystery,Sci-Fi
# Split                    1002           Horror,Thriller
# Sing                     1003   Animation,Comedy,Family
# Suicide Squad            1004  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes     1995       Crime,Drama,Mystery
# Hostel: Part II          1996                    Horror
# Step Up 2: The Streets   1997       Drama,Music,Romance
# Search Party             1998          Adventure,Comedy
# Nine Lives               1999     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
duplicate_df_rank.shape
#not working
# Out:
# (1000, 11)

# %%
duplicate_df.drop_duplicates(inplace=True,keep=)
#not working
# Out:
#   File "<ipython-input-170-5fac4161de81>", line 1
#     duplicate_df.drop_duplicates(inplace=True,keep=)
#                                                    ^
# SyntaxError: invalid syntax

# %%
movies_df.columns
# Out:
# Index(['Rank', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
movies_df.rename(columns= {
    "Description":"Desc",
    "Revenue (Millions)" : "Revenue",
    "Runtime (Minutes)":"Runtime"
},inplace = True)

# %%
movies_df.columns
# Out:
# Index(['Rank', 'Genre', 'Desc', 'Director', 'Actors', 'Year', 'Runtime',
#        'Rating', 'Votes', 'Revenue', 'Metascore'],
#       dtype='object')

# %%
movies_df
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy  1000   Action,Adventure,Sci-Fi
# Prometheus               1001  Adventure,Mystery,Sci-Fi
# Split                    1002           Horror,Thriller
# Sing                     1003   Animation,Comedy,Family
# Suicide Squad            1004  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes     1995       Crime,Drama,Mystery
# Hostel: Part II          1996                    Horror
# Step Up 2: The Streets   1997       Drama,Music,Romance
# Search Party             1998          Adventure,Comedy
# Nine Lives               1999     Comedy,Family,Fantasy
#
#                                                                       Desc  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
movies_df.columns
# Out:
# Index(['Rank', 'Genre', 'Desc', 'Director', 'Actors', 'Year', 'Runtime',
#        'Rating', 'Votes', 'Revenue', 'Metascore'],
#       dtype='object')

# %%
movies_df.values
# Out:
# array([[1000, 'Action,Adventure,Sci-Fi',
#         'A group of intergalactic criminals are forced to work together to stop a fanatical warrior from taking control of the universe.',
#         ..., 757074, 333.13, 76.0],
#        [1001, 'Adventure,Mystery,Sci-Fi',
#         'Following clues to the origin of mankind, a team finds a structure on a distant moon, but they soon realize they are not alone.',
#         ..., 485820, 126.46, 65.0],
#        [1002, 'Horror,Thriller',
#         'Three girls are kidnapped by a man with a diagnosed 23 distinct personalities. They must try to escape before the apparent emergence of a frightful new 24th.',
#         ..., 157606, 138.12, 62.0],
#        ...,
#        [1997, 'Drama,Music,Romance',
#         'Romantic sparks occur between two dance students from different backgrounds at the Maryland School of the Arts.',
#         ..., 70699, 58.01, 50.0],
#        [1998, 'Adventure,Comedy',
# ...

# %%
col_low = []
for col in movies_df:
    col = col.lower()
    col_low.append(col)
col_low
# Out:
# ['rank',
#  'genre',
#  'desc',
#  'director',
#  'actors',
#  'year',
#  'runtime',
#  'rating',
#  'votes',
#  'revenue',
#  'metascore']

# %%
for i in movies_df:
    print(i)
# Out:
# Rank
# Genre
# Desc
# Director
# Actors
# Year
# Runtime
# Rating
# Votes
# Revenue
# Metascore

# %%
for i in movies_df.values:
    print(i)
# Out:
# [1000 'Action,Adventure,Sci-Fi'
#  'A group of intergalactic criminals are forced to work together to stop a fanatical warrior from taking control of the universe.'
#  'James Gunn' 'Chris Pratt, Vin Diesel, Bradley Cooper, Zoe Saldana' 2014
#  121 8.1 757074 333.13 76.0]
# [1001 'Adventure,Mystery,Sci-Fi'
#  'Following clues to the origin of mankind, a team finds a structure on a distant moon, but they soon realize they are not alone.'
#  'Ridley Scott'
#  'Noomi Rapace, Logan Marshall-Green, Michael Fassbender, Charlize Theron'
#  2012 124 7.0 485820 126.46 65.0]
# [1002 'Horror,Thriller'
#  'Three girls are kidnapped by a man with a diagnosed 23 distinct personalities. They must try to escape before the apparent emergence of a frightful new 24th.'
#  'M. Night Shyamalan'
#  'James McAvoy, Anya Taylor-Joy, Haley Lu Richardson, Jessica Sula' 2016
#  117 7.3 157606 138.12 62.0]
# [1003 'Animation,Comedy,Family'
# ...

# %%
movies_df.columns = col_low
movies_df
# Out:
#                          rank                     genre  \
# Title
# Guardians of the Galaxy  1000   Action,Adventure,Sci-Fi
# Prometheus               1001  Adventure,Mystery,Sci-Fi
# Split                    1002           Horror,Thriller
# Sing                     1003   Animation,Comedy,Family
# Suicide Squad            1004  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes     1995       Crime,Drama,Mystery
# Hostel: Part II          1996                    Horror
# Step Up 2: The Streets   1997       Drama,Music,Romance
# Search Party             1998          Adventure,Comedy
# Nine Lives               1999     Comedy,Family,Fantasy
#
#                                                                       desc  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
sample_df = movies_df.loc[:,['rank','year']]

# %%
sample_df
# Out:
#                          rank  year
# Title
# Guardians of the Galaxy  1000  2014
# Prometheus               1001  2012
# Split                    1002  2016
# Sing                     1003  2016
# Suicide Squad            1004  2016
# ...                       ...   ...
# Secret in Their Eyes     1995  2015
# Hostel: Part II          1996  2007
# Step Up 2: The Streets   1997  2008
# Search Party             1998  2014
# Nine Lives               1999  2016
#
# [1000 rows x 2 columns]

# %%
sample_df = movies_df.loc[(movies_df['rank'] == 1003) & (movies_df['year'] == 2016)]
sample_df
# Out:
#        rank                    genre  \
# Title
# Sing   1003  Animation,Comedy,Family
#
#                                                     desc  \
# Title
# Sing   In a city of humanoid animals, a hustling thea...
#
#                    director  \
# Title
# Sing   Christophe Lourdelet
#
#                                                   actors  year  runtime  \
# Title
# Sing   Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016      108
#
#        rating  votes  revenue  metascore
# Title
# Sing      7.2  60545   270.32       59.0

# %%
for i in movies_df['genre']:
    if type(i) == str:
        print('Yes')
# Out:
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# ...

# %%
list1 = list(movies_df.values)
list1
# Out:
# [array([1000, 'Action,Adventure,Sci-Fi',
#         'A group of intergalactic criminals are forced to work together to stop a fanatical warrior from taking control of the universe.',
#         'James Gunn',
#         'Chris Pratt, Vin Diesel, Bradley Cooper, Zoe Saldana', 2014, 121,
#         8.1, 757074, 333.13, 76.0], dtype=object),
#  array([1001, 'Adventure,Mystery,Sci-Fi',
#         'Following clues to the origin of mankind, a team finds a structure on a distant moon, but they soon realize they are not alone.',
#         'Ridley Scott',
#         'Noomi Rapace, Logan Marshall-Green, Michael Fassbender, Charlize Theron',
#         2012, 124, 7.0, 485820, 126.46, 65.0], dtype=object),
#  array([1002, 'Horror,Thriller',
#         'Three girls are kidnapped by a man with a diagnosed 23 distinct personalities. They must try to escape before the apparent emergence of a frightful new 24th.',
#         'M. Night Shyamalan',
# ...

# %% [markdown]
# # Null Values

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   rank       1000 non-null   int32
#  1   genre      1000 non-null   object
#  2   desc       1000 non-null   object
#  3   director   1000 non-null   object
#  4   actors     1000 non-null   object
#  5   year       1000 non-null   int64
#  6   runtime    1000 non-null   int64
#  7   rating     1000 non-null   float64
#  8   votes      1000 non-null   int64
#  9   revenue    872 non-null    float64
#  10  metascore  936 non-null    float64
# dtypes: float64(3), int32(1), int64(3), object(4)
# memory usage: 129.8+ KB

# %%
movies_df.isna().sum()
# Out:
# rank           0
# genre          0
# desc           0
# director       0
# actors         0
# year           0
# runtime        0
# rating         0
# votes          0
# revenue      128
# metascore     64
# dtype: int64

# %%
movies_df[movies_df['metascore'].isna() == True]
# Out:
#                          rank                      genre  \
# Title
# Paris pieds nus          1025                     Comedy
# Bahubali: The Beginning  1026     Action,Adventure,Drama
# Dead Awake               1027            Horror,Thriller
# 5- 25- 77                1039               Comedy,Drama
# Don't Fuck in the Woods  1042                     Horror
# ...                       ...                        ...
# The Walk                 1967  Adventure,Biography,Crime
# The Lone Ranger          1969   Action,Adventure,Western
# Disturbia                1971     Drama,Mystery,Thriller
# Selma                    1989    Biography,Drama,History
# Take Me Home Tonight     1992       Comedy,Drama,Romance
#
#                                                                       desc  \
# Title
# Paris pieds nus          Fiona visits Paris for the first time to assis...
# Bahubali: The Beginning  In ancient India, an adventurous and daring ma...
# ...

# %%
movies_df.isna().sum()
# Out:
# rank           0
# genre          0
# desc           0
# director       0
# actors         0
# year           0
# runtime        0
# rating         0
# votes          0
# revenue      128
# metascore     64
# dtype: int64

# %%
movies_df = movies_df.dropna()

# %%
movies_df.shape
# Out:
# (838, 11)

# %%
movies_df.describe()
# Out:
#               rank        year     runtime      rating         votes  \
# count   838.000000   838.00000  838.000000  838.000000  8.380000e+02
# mean   1484.247017  2012.50716  114.638425    6.814320  1.932303e+05
# std     286.572065     3.17236   18.470922    0.877754  1.930990e+05
# min    1000.000000  2006.00000   66.000000    1.900000  1.780000e+02
# 25%    1237.250000  2010.00000  101.000000    6.300000  6.127650e+04
# 50%    1474.500000  2013.00000  112.000000    6.900000  1.368795e+05
# 75%    1728.750000  2015.00000  124.000000    7.500000  2.710830e+05
# max    1999.000000  2016.00000  187.000000    9.000000  1.791916e+06
#
#           revenue   metascore
# count  838.000000  838.000000
# mean    84.564558   59.575179
# std    104.520227   16.952416
# min      0.000000   11.000000
# 25%     13.967500   47.000000
# 50%     48.150000   60.000000
# 75%    116.800000   72.000000
# max    936.630000  100.000000

# %%
movies_df['year'].describe()
# Out:
# count     838.00000
# mean     2012.50716
# std         3.17236
# min      2006.00000
# 25%      2010.00000
# 50%      2013.00000
# 75%      2015.00000
# max      2016.00000
# Name: year, dtype: float64

# %%
movies_df['genre'].value_counts().head(10)
# Out:
# Action,Adventure,Sci-Fi       50
# Comedy,Drama,Romance          30
# Drama                         29
# Drama,Romance                 27
# Animation,Adventure,Comedy    26
# Comedy                        26
# Action,Adventure,Fantasy      25
# Comedy,Drama                  24
# Comedy,Romance                22
# Crime,Drama,Thriller          18
# Name: genre, dtype: int64

# %%
movies_df.count()
# Out:
# rank         838
# genre        838
# desc         838
# director     838
# actors       838
# year         838
# runtime      838
# rating       838
# votes        838
# revenue      838
# metascore    838
# dtype: int64

# %%
movies_df.corr()
# Out:
#                rank      year   runtime    rating     votes   revenue  \
# rank       1.000000 -0.312809 -0.254783 -0.243125 -0.303284 -0.273170
# year      -0.312809  1.000000 -0.101933 -0.145703 -0.362445 -0.129198
# runtime   -0.254783 -0.101933  1.000000  0.374566  0.399298  0.281721
# rating    -0.243125 -0.145703  0.374566  1.000000  0.517452  0.217106
# votes     -0.303284 -0.362445  0.399298  0.517452  1.000000  0.636833
# revenue   -0.273170 -0.129198  0.281721  0.217106  0.636833  1.000000
# metascore -0.195909 -0.062303  0.221397  0.672731  0.332674  0.142397
#
#            metascore
# rank       -0.195909
# year       -0.062303
# runtime     0.221397
# rating      0.672731
# votes       0.332674
# revenue     0.142397
# metascore   1.000000

# %%
cond = movies_df['director'] == 'David Ayer'
cond.head()
# Out:
# Title
# Guardians of the Galaxy    False
# Prometheus                 False
# Split                      False
# Sing                       False
# Suicide Squad               True
# Name: director, dtype: bool

# %%
movies_df[(movies_df['rating']) > 8.3].head(10)
# Out:
#                        rank                    genre  \
# Title
# Interstellar           1036   Adventure,Drama,Sci-Fi
# The Dark Knight        1054       Action,Crime,Drama
# The Prestige           1064     Drama,Mystery,Sci-Fi
# Inception              1080  Action,Adventure,Sci-Fi
# Kimi no na wa          1096  Animation,Drama,Fantasy
# The Departed           1099     Crime,Drama,Thriller
# The Dark Knight Rises  1124          Action,Thriller
# Whiplash               1133              Drama,Music
# Django Unchained       1144            Drama,Western
# The Intouchables       1249   Biography,Comedy,Drama
#
#                                                                     desc  \
# Title
# Interstellar           A team of explorers travel through a wormhole ...
# The Dark Knight        When the menace known as the Joker wreaks havo...
# The Prestige           Two stage magicians engage in competitive one-...
# ...

# %%
movies_df.loc[(movies_df['year'] == 2016) | (movies_df['runtime'] == 87)]
# Out:
#                             rank                     genre  \
# Title
# Split                       1002           Horror,Thriller
# Sing                        1003   Animation,Comedy,Family
# Suicide Squad               1004  Action,Adventure,Fantasy
# The Great Wall              1005  Action,Adventure,Fantasy
# La La Land                  1006        Comedy,Drama,Music
# ...                          ...                       ...
# Kicks                       1949                 Adventure
# Queen of Katwe              1974     Biography,Drama,Sport
# My Big Fat Greek Wedding 2  1975     Comedy,Family,Romance
# Miracles from Heaven        1980    Biography,Drama,Family
# Nine Lives                  1999     Comedy,Family,Fantasy
#
#                                                                          desc  \
# Title
# Split                       Three girls are kidnapped by a man with a diag...
# Sing                        In a city of humanoid animals, a hustling thea...
# ...

# %%
movies_df[movies_df['year'].isin([2016])].head()
# Out:
#                 rank                     genre  \
# Title
# Split           1002           Horror,Thriller
# Sing            1003   Animation,Comedy,Family
# Suicide Squad   1004  Action,Adventure,Fantasy
# The Great Wall  1005  Action,Adventure,Fantasy
# La La Land      1006        Comedy,Drama,Music
#
#                                                              desc  \
# Title
# Split           Three girls are kidnapped by a man with a diag...
# Sing            In a city of humanoid animals, a hustling thea...
# Suicide Squad   A secret government agency recruits some of th...
# The Great Wall  European mercenaries searching for black powde...
# La La Land      A jazz pianist falls for an aspiring actress i...
#
#                             director  \
# Title
# Split             M. Night Shyamalan
# Sing            Christophe Lourdelet
# Suicide Squad             David Ayer
# The Great Wall           Yimou Zhang
# La La Land           Damien Chazelle
#
# ...
